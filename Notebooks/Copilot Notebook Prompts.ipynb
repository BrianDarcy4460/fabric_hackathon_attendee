# %%
#In a Fabric PySpark notebook, generate an end‑to‑end notebook for normalizing
# SIS data from an Azure SQL mirror into a Silver Lakehouse. 
# The notebook must be tenant‑ and workspace‑agnostic: do not hardcode any 
#GUIDs or tenant IDs anywhere. Always resolve the current workspace id 
# and the “SIS Mirror” item id at runtime via the Fabric REST API.

#“In this Fabric PySpark notebook, add a helper function to_snake(name: str) 
#that converts column names to snake_case (splitting CamelCase/PascalCase, 
#handling acronyms, then lower‑casing and joining with _). Then, in the 
#DataFrame load step, rename all columns by applying to_snake to each column 
# name so the final table uses snake_case column names instead of the 
# original ones.”
